# %%
# Import library yang diperlukan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Baca dataset
df = pd.read_csv('median_average_wages.csv')

# %%
# Tampilkan 5 baris pertama dari dataset untuk mendapatkan gambaran awal
print(df.head())
# Out:
#    year  median  average  men_median  men_average  women_median  \
# 0  2022   22.88    32.00       24.91        35.82         20.74
# 1  2021   23.05    32.08       24.93        35.61         21.46
# 2  2020   23.64    32.54       25.95        36.03         21.72
# 3  2019   22.12    30.36       24.04        33.65         20.42
# 4  2018   21.90    29.83       23.42        33.19         19.73
#
#    women_average  white_median  white_average  black_median  ...  \
# 0          27.86         24.96          34.49         19.60  ...
# 1          28.28         25.40          34.50         19.45  ...
# 2          28.75         25.98          34.86         19.85  ...
# 3          26.83         24.39          32.79         18.45  ...
# 4          26.21         23.97          32.44         17.57  ...
#
#    black_women_median  black_women_average  hispanic_women_median  \
# 0               19.00                23.99                  17.54
# ...

# %%
# Informasi dasar tentang dataset: tipe data, jumlah data non-null, dll.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   year                               50 non-null     int64
#  1   median                             50 non-null     float64
#  2   average                            50 non-null     float64
#  3   men_median                         50 non-null     float64
#  4   men_average                        50 non-null     float64
#  5   women_median                       50 non-null     float64
#  6   women_average                      50 non-null     float64
#  7   white_median                       50 non-null     float64
#  8   white_average                      50 non-null     float64
#  9   black_median                       50 non-null     float64
#  10  black_average                      50 non-null     float64
# ...

# %%
# Statistik deskriptif untuk setiap kolom numerik
print(df.describe())
# Out:
#              year     median    average  men_median  men_average  \
# count    50.00000  50.000000  50.000000   50.000000    50.000000
# mean   1997.50000  20.261600  25.564600   23.241000    28.921400
# std      14.57738   1.214325   2.848557    0.912702     2.706539
# min    1973.00000  18.780000  22.420000   21.510000    26.200000
# 25%    1985.25000  19.280000  23.045000   22.815000    26.630000
# 50%    1997.50000  19.810000  24.550000   23.360000    27.855000
# 75%    2009.75000  21.107500  27.335000   23.765000    30.185000
# max    2022.00000  23.640000  32.540000   25.950000    36.030000
#
#        women_median  women_average  white_median  white_average  black_median  \
# count      50.00000      50.000000     50.000000       50.00000     50.000000
# mean       17.59580      21.699400     21.692200       27.03100     17.097400
# std         1.90173       3.362138      1.755276        3.46881      1.077739
# ...

# %%
# Visualisasi distribusi fitur numerik
numerical_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

# %%
for feature in numerical_features:
    plt.figure(figsize=(12, 6))
    sns.histplot(df[feature], bins=30, kde=True)
    plt.title(f'Distribusi untuk {feature}')
    plt.show()

# %%
"PURPLE TUESDAY (feat. Joey Bada$$ & Jesse Boykins III)".replace('$', '$$')
# Out:
# 'PURPLE TUESDAY (feat. Joey Bada$$$$ & Jesse Boykins III)'

# %%
r"PURPLE TUESDAY (feat. Joey Bada$$ & Jesse Boykins III)"
# Out:
# 'PURPLE TUESDAY (feat. Joey Bada$$ & Jesse Boykins III)'

# %%
# Visualisasi hubungan antara dua fitur menggunakan scatter plot untuk fitur-fitur yang relevan
sns.scatterplot(x='year', y='median', data=df)
plt.show()

# %%
# Boxplot untuk fitur terhadap target/kategori tertentu, misal 'genre'
sns.boxplot(x='year', y='median', data=df)
plt.xticks(rotation=45)  # Rotasi label x-axis untuk keterbacaan yang lebih baik jika perlu
plt.show()

# %%
# Korelasi antar fitur
corr_matrix = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Korelasi Antar Fitur')
plt.show()
